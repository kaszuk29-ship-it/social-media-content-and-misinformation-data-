# %%
import pandas as pd
df= pd.read_csv("social media content and misinformation data.csv")
df
# Out:
#      Platform Content_Type Post_ID             Timestamp  User_Followers  \
# 0     Twitter        Tweet  tw_001  2024-08-13T09:15:23Z           15420
# 1    Facebook         Post  fb_002  2024-08-13T11:32:45Z            8934
# 2   Instagram        Story  ig_003  2024-08-13T14:21:12Z          234567
# 3     YouTube        Video  yt_004  2024-08-13T16:45:33Z          567890
# 4      TikTok        Video  tk_005  2024-08-13T18:22:11Z          123456
# 5    LinkedIn         Post  ln_006  2024-08-13T10:12:44Z            5678
# 6      Reddit         Post  rd_007  2024-08-13T20:33:17Z             234
# 7     Twitter        Tweet  tw_008  2024-08-13T07:45:22Z           89234
# 8    Facebook         Post  fb_009  2024-08-13T13:17:55Z           12345
# 9   Instagram         Post  ig_010  2024-08-13T15:44:28Z           45678
# 10    YouTube        Video  yt_011  2024-08-13T19:23:41Z          345678
# 11     TikTok        Video  tk_012  2024-08-13T21:15:37Z           78901
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 25 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Platform              40 non-null     object
#  1   Content_Type          40 non-null     object
#  2   Post_ID               40 non-null     object
#  3   Timestamp             40 non-null     object
#  4   User_Followers        40 non-null     int64
#  5   Content_Text          40 non-null     object
#  6   Language              40 non-null     object
#  7   Country               40 non-null     object
#  8   Engagement_Score      40 non-null     float64
#  9   Like_Count            40 non-null     int64
#  10  Share_Count           40 non-null     int64
#  11  Comment_Count         40 non-null     int64
#  12  Verification_Status   40 non-null     object
#  13  Content_Category      40 non-null     object
#  14  Misinformation_Flag   40 non-null     object
# ...

# %%
df.describe()
# Out:
#        User_Followers  Engagement_Score   Like_Count  Share_Count  \
# count       40.000000         40.000000    40.000000    40.000000
# mean    177132.900000          0.643500  1572.425000   364.675000
# std     199374.861798          0.311568  1701.807921   451.666509
# min        234.000000          0.060000    12.000000     3.000000
# 25%      21447.000000          0.332500   317.250000    83.500000
# 50%      89123.000000          0.820000   839.500000   234.000000
# 75%     234814.250000          0.882500  2345.000000   456.000000
# max     678901.000000          0.950000  6789.000000  2345.000000
#
#        Comment_Count  Sentiment_Score  Toxicity_Score  Content_Length_Chars  \
# count      40.000000        40.000000       40.000000             40.000000
# mean      329.350000         0.352500        0.279750            127.700000
# std       275.906204         0.642662        0.330861            102.048556
# ...

# %%
mean_value = df["Like_Count"].mean()
print("mean:",mean_value)
# Out:
# mean: 1572.425

# %%
median_value = df["Share_Count"].median()
print("median:",median_value)
# Out:
# median: 234.0

# %%
mode_value = df["Comment_Count"].mode()[0]
print("mode:",mode_value)
# Out:
# mode: 234

# %%
df.head()
# Out:
#     Platform Content_Type Post_ID             Timestamp  User_Followers  \
# 0    Twitter        Tweet  tw_001  2024-08-13T09:15:23Z           15420
# 1   Facebook         Post  fb_002  2024-08-13T11:32:45Z            8934
# 2  Instagram        Story  ig_003  2024-08-13T14:21:12Z          234567
# 3    YouTube        Video  yt_004  2024-08-13T16:45:33Z          567890
# 4     TikTok        Video  tk_005  2024-08-13T18:22:11Z          123456
#
#                                         Content_Text Language         Country  \
# 0  Climate change is just a natural cycle - the E...  English   United States
# 1  New vaccine study shows 99% effectiveness agai...  English  United Kingdom
# 2  Just got my booster shot! Feeling protected an...  English          Canada
# 3  Documentary: The Real Truth About Election Sec...  English   United States
# 4  5G towers cause health problems - here's the p...  English       Australia
#
# ...

# %%
df.head(3)
# Out:
#     Platform Content_Type Post_ID             Timestamp  User_Followers  \
# 0    Twitter        Tweet  tw_001  2024-08-13T09:15:23Z           15420
# 1   Facebook         Post  fb_002  2024-08-13T11:32:45Z            8934
# 2  Instagram        Story  ig_003  2024-08-13T14:21:12Z          234567
#
#                                         Content_Text Language         Country  \
# 0  Climate change is just a natural cycle - the E...  English   United States
# 1  New vaccine study shows 99% effectiveness agai...  English  United Kingdom
# 2  Just got my booster shot! Feeling protected an...  English          Canada
#
#    Engagement_Score  Like_Count  ...  Fact_Check_Source  Sentiment_Score  \
# 0              0.72         234  ...            Reuters             0.23
# 1              0.89         567  ...                NHS             0.78
# 2              0.94        1234  ...                NaN             0.91
#
#   Toxicity_Score Political_Leaning                   Topic_Tags  \
# ...

# %%
df.tail()
# Out:
#      Platform Content_Type Post_ID             Timestamp  User_Followers  \
# 35     Reddit         Post  rd_036  2024-08-15T19:45:23Z            2345
# 36   Facebook         Live  fb_037  2024-08-15T14:22:41Z           89456
# 37  Instagram         Reel  ig_038  2024-08-15T17:33:55Z          123567
# 38    Twitter        Tweet  tw_039  2024-08-15T20:15:44Z          678901
# 39    YouTube        Video  yt_040  2024-08-15T22:41:18Z          234890
#
#                                          Content_Text Language        Country  \
# 35  Chemtrails are real and they're poisoning our ...  English  United States
# 36  Live Q&A with climate scientists about extreme...  English        Germany
# 37  Quick tutorial on identifying misinformation i...  English         Canada
# 38  Electric grid can't handle renewable energy - ...  English  United States
# 39  Complete beginner's guide to understanding blo...  English      Singapore
#
# ...

# %%
df.isnull()
# Out:
#     Platform  Content_Type  Post_ID  Timestamp  User_Followers  Content_Text  \
# 0      False         False    False      False           False         False
# 1      False         False    False      False           False         False
# 2      False         False    False      False           False         False
# 3      False         False    False      False           False         False
# 4      False         False    False      False           False         False
# 5      False         False    False      False           False         False
# 6      False         False    False      False           False         False
# 7      False         False    False      False           False         False
# 8      False         False    False      False           False         False
# 9      False         False    False      False           False         False
# 10     False         False    False      False           False         False
# ...

# %%
df.isnull().head()
# Out:
#    Platform  Content_Type  Post_ID  Timestamp  User_Followers  Content_Text  \
# 0     False         False    False      False           False         False
# 1     False         False    False      False           False         False
# 2     False         False    False      False           False         False
# 3     False         False    False      False           False         False
# 4     False         False    False      False           False         False
#
#    Language  Country  Engagement_Score  Like_Count  ...  Fact_Check_Source  \
# 0     False    False             False       False  ...              False
# 1     False    False             False       False  ...              False
# 2     False    False             False       False  ...               True
# 3     False    False             False       False  ...              False
# 4     False    False             False       False  ...              False
#
# ...

# %%
df.isnull().sum()
# Out:
# Platform                 0
# Content_Type             0
# Post_ID                  0
# Timestamp                0
# User_Followers           0
# Content_Text             0
# Language                 0
# Country                  0
# Engagement_Score         0
# Like_Count               0
# Share_Count              0
# Comment_Count            0
# Verification_Status      0
# Content_Category         0
# Misinformation_Flag      0
# Fact_Check_Source       13
# Sentiment_Score          0
# Toxicity_Score           0
# Political_Leaning        0
# Topic_Tags               0
# Content_Length_Chars     0
# Media_Type               0
# Has_External_Link        0
# Viral_Score              0
# Moderation_Action        0
# dtype: int64

# %%
df.head()
# Out:
#     Platform Content_Type Post_ID             Timestamp  User_Followers  \
# 0    Twitter        Tweet  tw_001  2024-08-13T09:15:23Z           15420
# 1   Facebook         Post  fb_002  2024-08-13T11:32:45Z            8934
# 2  Instagram        Story  ig_003  2024-08-13T14:21:12Z          234567
# 3    YouTube        Video  yt_004  2024-08-13T16:45:33Z          567890
# 4     TikTok        Video  tk_005  2024-08-13T18:22:11Z          123456
#
#                                         Content_Text Language         Country  \
# 0  Climate change is just a natural cycle - the E...  English   United States
# 1  New vaccine study shows 99% effectiveness agai...  English  United Kingdom
# 2  Just got my booster shot! Feeling protected an...  English          Canada
# 3  Documentary: The Real Truth About Election Sec...  English   United States
# 4  5G towers cause health problems - here's the p...  English       Australia
#
# ...

# %%
import numpy as n
df["Like_Count"].replace("",n.nan,inplace=True)
# Out:
# <ipython-input-16-d1ee9f3700be>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Like_Count"].replace("",n.nan,inplace=True)

# %%
df.isnull().sum()
df.replace("",n.nan,inplace=True)

# %%
df["Comment_Count"]=pd.to_numeric(df["Comment_Count"],errors="coerce")
df["Comment_Count"].fillna(df["Comment_Count"].mean(),inplace=True)
# Out:
# <ipython-input-19-446bee374c08>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Comment_Count"].fillna(df["Comment_Count"].mean(),inplace=True)

# %%
df["Comment_Count"]
# Out:
# 0      156
# 1       89
# 2       67
# 3      890
# 4      234
# 5       78
# 6       89
# 7      234
# 8      145
# 9      123
# 10     567
# 11     789
# 12     567
# 13      45
# 14     234
# 15      89
# 16     234
# 17     456
# 18     345
# 19     789
# 20     156
# 21      67
# 22     234
# 23     456
# 24     345
# 25    1234
# 26     567
# 27      67
# 28     456
# 29     234
# 30      67
# 31     234
# 32     456
# 33     345
# 34      89
# 35     123
# 36     789
# 37     234
# 38     567
# 39     234
# Name: Comment_Count, dtype: int64

# %%
df["Comment_Count"].fillna(df["Comment_Count"].median(),inplace=True)

# %%
df["Comment_Count"]
# Out:
# 0      156
# 1       89
# 2       67
# 3      890
# 4      234
# 5       78
# 6       89
# 7      234
# 8      145
# 9      123
# 10     567
# 11     789
# 12     567
# 13      45
# 14     234
# 15      89
# 16     234
# 17     456
# 18     345
# 19     789
# 20     156
# 21      67
# 22     234
# 23     456
# 24     345
# 25    1234
# 26     567
# 27      67
# 28     456
# 29     234
# 30      67
# 31     234
# 32     456
# 33     345
# 34      89
# 35     123
# 36     789
# 37     234
# 38     567
# 39     234
# Name: Comment_Count, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df["Country-encoded"]=le.fit_transform(df["Country"])
df["Country-encoded"],df["Country"]
# Out:
# (0     12
#  1     11
#  2      2
#  3     12
#  4      0
#  5      4
#  6     12
#  7      6
#  8      1
#  9     10
#  10    12
#  11     9
#  12    12
#  13    12
#  14    12
#  15     2
#  16     7
#  17    12
#  18     5
#  19    12
#  20    11
#  21     0
#  22     3
#  23     2
#  24    12
#  25    12
#  26     1
#  27     4
#  28    12
#  29    12
#  30     0
#  31    11
#  32     2
#  33    12
#  34    10
#  35    12
#  36     4
#  37     2
#  38    12
#  39     8
#  Name: Country-encoded, dtype: int32,
#  0      United States
#  1     United Kingdom
#  2             Canada
#  3      United States
#  4          Australia
#  5            Germany
#  6      United States
#  7              Japan
#  8             Brazil
#  9             Sweden
#  10     United States
#  11       South Korea
#  12     United States
#  13     United States
#  14     United States
#  15            Canada
#  16       Netherlands
#  17     United States
#  18             India
#  19     United States
# ...
